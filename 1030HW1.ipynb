# %% [markdown]
# ## Yahoo股市-光電業

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
# python 裡的excel
import pandas as pd

# %%
df_temp = pd.read_html('https://tw.stock.yahoo.com/s/list.php?c=%A5%FA%B9q&rr=0.29349700%201573386287',
                     encoding='big5')
len(df_temp)
# Out:
# 6

# %%
df = df_temp[3]
df.head()
column_name = df.loc[0, :]
df.columns = column_name
df.drop("選擇", axis=1, inplace=True)
df.drop(0)
# Out:
# 0          股票代號     時間     成交     買進     賣出     漲跌     張數     昨收     開盤  \
# 1       2323 中環  14:30  10.80  10.80  10.85  ▽0.05   7739  10.85  10.95
# 2       2340 光磊  14:30  24.55  24.55  24.60  ▽0.25   2436  24.80  24.85
# 3       2349 錸德  14:30   7.81   7.81   7.82  ▽0.01   2293   7.82   7.91
# 4       2374 佳能  13:30  16.75  16.75  16.80   0.00    318  16.75  16.75
# 5       2393 億光  14:30  28.35  28.35  28.40  ▽0.20   1183  28.55  28.65
# 6       2406 國碩  14:30   7.03   7.03   7.04  ▽0.02    881   7.05   7.05
# 7       2409 友達  14:30   8.04   8.04   8.06  ▽0.16  44671   8.20   8.18
# 8       2426 鼎元  14:30  14.50  14.50  14.55   0.00    381  14.50  14.60
# 9       2438 翔耀  12:58   5.98   5.90   5.99  ▽0.02     42   6.00   6.00
# 10      2448 晶電  14:30  28.80  28.80  28.85  △0.50  15971  28.30  28.80
# 11     2466 冠西電  13:30  33.65  33.55  33.65  △0.10     86  33.55  33.55
# 12      2486 一詮  13:30   8.04   8.03   8.05  ▽0.06    429   8.10   8.10
# ...
