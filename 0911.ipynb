# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
y1 = np.linspace(-6, 6, 5)
x1 = 3*np.abs(y1)+2
y2 = np.linspace(-6, 6, 5)
x2 = 0 - 3 * np.abs(y2) - 2
y3 = np.sin(x1) - 7
plt.xkcd()
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x1-10, y3)
