# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('8da22fb395b8af2c90fa934a3921f1be_export.csv')

# %%
train[:]
# Out:
#    Site county  PM25  DataCreationDate ItemUnit
# 0    崙背    雲林縣  40.0  2019-11-01 10:00    μg/m3
# 1   富貴角    新北市   8.0  2019-11-01 10:00    μg/m3
# 2    麥寮    雲林縣  15.0  2019-11-01 10:00    μg/m3
# 3    關山    臺東縣   2.0  2019-11-01 10:00    μg/m3
# 4    馬公    澎湖縣  11.0  2019-11-01 10:00    μg/m3
# 5    金門    金門縣  20.0  2019-11-01 10:00    μg/m3
# 6    馬祖    連江縣  11.0  2019-11-01 10:00    μg/m3
# 7    埔里    南投縣  35.0  2019-11-01 10:00    μg/m3
# 8    復興    高雄市  28.0  2019-11-01 10:00    μg/m3
# 9    永和    新北市   8.0  2019-11-01 10:00    μg/m3
# 10   竹山    南投縣  32.0  2019-11-01 10:00    μg/m3
# 11   中壢    桃園市  12.0  2019-11-01 10:00    μg/m3
# 12   三重    新北市  12.0  2019-11-01 10:00    μg/m3
# 13   冬山    宜蘭縣  35.0  2019-11-01 10:00    μg/m3
# 14   宜蘭    宜蘭縣  10.0  2019-11-01 10:00    μg/m3
# 15   陽明    臺北市   1.0  2019-11-01 10:00    μg/m3
# 16   花蓮    花蓮縣  15.0  2019-11-01 10:00    μg/m3
# 17   臺東    臺東縣  18.0  2019-11-01 10:00    μg/m3
# 18   恆春    屏東縣  15.0  2019-11-01 10:00    μg/m3
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
taipei = train[train.county == '臺北市']

# %%
taipei
taipei.Site
# Out:
# 15    陽明
# 62    大同
# 63    松山
# 64    古亭
# 65    萬華
# 66    中山
# 67    士林
# Name: Site, dtype: object

# %%
Site = ['陽明', '大同', '松山', '古亭', '萬華', '中山', '士林']
PM25 = [1.0, 9.0, 9.0, 8.0, 8.0, 0, 4.0]
plt.xlabel('Site')
plt.ylabel('PM25')
plt.scatter(Site, PM25)
